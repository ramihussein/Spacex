# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (1.12)
# Requirement already satisfied: plotly in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (5.11.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: future in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: brotli in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: jupyter_dash in c:\users\rami.hussein\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ansi2html in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: requests in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: ipykernel in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: flask in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: dash in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ipython in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: nest-asyncio in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (1.5.1)
# Requirement already satisfied: retrying in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: future in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: flask-compress in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.12)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: plotly in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.11.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rami.hussein\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\rami.hussein\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: pygments in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: pickleshare in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: decorator in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: colorama in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\rami.hussein\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\rami.hussein\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\rami.hussein\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\rami.hussein\appdata\roaming\python\python38\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\rami.hussein\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\rami.hussein\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rami.hussein\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rami.hussein\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rami.hussein\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: plotly in c:\users\rami.hussein\anaconda3\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rami.hussein\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# C:\Users\rami.hussein\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rami.hussein\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\rami.hussein\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',options=[
                                    {'label': 'All Sites', 'value': 'ALL'},
                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                ],
                                value='ALL',
                                placeholder="Select a Launch Site",
                                searchable=True),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart',component_property='figure'),
Input(component_id='site_dropdown',component_property='value'))
def get_pie_chart(entered_site):
    filtered_df=spacex_df
    if entered_site=='All':
        fig=px.pie(spacex_df,values='class',
        names='Launch Site',
        title='Success Count for all launch sites')
        return fig
    else:
        df_site_filtered=spacex_df[spacex_df['Launch Site']==site]
        filtered_df=spacex_df[spacex_df['Launch Site']==site_dropdown]
        df1=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(df1,values='class',names='Launch Site',title='Success count for'+ site)
        return fig
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(site,payload):
    low, high = (payload[0],payload[1])
    mask=spacex_df[spacex_df['Payload Mass (kg)'].between(low,high)]
    if site=='ALL':
        fig=px.scatter(mask,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        mask_filtered=mask[mask['Launch Site']==site]
        fig=px.scatter(mask_filtered,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload Mass for' + site)
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='jupyterlab', port = 8070,dev_tools_ui=True, #debug=True,
              dev_tools_hot_reload =True, threaded=True)
